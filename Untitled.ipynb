# %%
# Out:
# Collecting git+https://github.com/RomelTorres/alpha_vantage.git@develop
#   Cloning https://github.com/RomelTorres/alpha_vantage.git (to revision develop) to /private/var/folders/g9/rjngf18d4rq4mrz22mz347740000gn/T/pip-req-build-unkzky91
#   Running command git clone -q https://github.com/RomelTorres/alpha_vantage.git /private/var/folders/g9/rjngf18d4rq4mrz22mz347740000gn/T/pip-req-build-unkzky91
# Collecting aiohttp
#   Downloading aiohttp-3.6.2-cp37-cp37m-macosx_10_13_x86_64.whl (642 kB)
#      |████████████████████████████████| 642 kB 1.5 MB/s eta 0:00:01
# Requirement already satisfied: requests in /Users/leonardogomescardoso/opt/anaconda3/envs/case_7.1/lib/python3.7/site-packages (from alpha-vantage==2.1.3) (2.23.0)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.4.2-cp37-cp37m-macosx_10_13_x86_64.whl (125 kB)
#      |████████████████████████████████| 125 kB 12.6 MB/s eta 0:00:01
# Requirement already satisfied: chardet<4.0,>=2.0 in /Users/leonardogomescardoso/opt/anaconda3/envs/case_7.1/lib/python3.7/site-packages (from aiohttp->alpha-vantage==2.1.3) (3.0.4)
# Requirement already satisfied: attrs>=17.3.0 in /Users/leonardogomescardoso/opt/anaconda3/envs/case_7.1/lib/python3.7/site-packages (from aiohttp->alpha-vantage==2.1.3) (19.3.0)
# Collecting multidict<5.0,>=4.5
#   Downloading multidict-4.7.5-cp37-cp37m-macosx_10_13_x86_64.whl (48 kB)
#      |████████████████████████████████| 48 kB 6.9 MB/s  eta 0:00:01
# Collecting async-timeout<4.0,>=3.0
#   Downloading async_timeout-3.0.1-py3-none-any.whl (8.2 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/leonardogomescardoso/opt/anaconda3/envs/case_7.1/lib/python3.7/site-packages (from requests->alpha-vantage==2.1.3) (2019.11.28)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/leonardogomescardoso/opt/anaconda3/envs/case_7.1/lib/python3.7/site-packages (from requests->alpha-vantage==2.1.3) (1.25.7)
# Requirement already satisfied: idna<3,>=2.5 in /Users/leonardogomescardoso/opt/anaconda3/envs/case_7.1/lib/python3.7/site-packages (from requests->alpha-vantage==2.1.3) (2.9)
# Building wheels for collected packages: alpha-vantage
#   Building wheel for alpha-vantage (setup.py) ... done
#   Created wheel for alpha-vantage: filename=alpha_vantage-2.1.3-py3-none-any.whl size=25572 sha256=86c55e11771695563d93a0d3cead5cc64b3ed8e09c5dbb726192a756927815c6
#   Stored in directory: /private/var/folders/g9/rjngf18d4rq4mrz22mz347740000gn/T/pip-ephem-wheel-cache-8suy8acs/wheels/8a/78/79/ab431232079a7b6bcf2f05a795a2f41c2402a06eeaec0220aa
# Successfully built alpha-vantage
# Installing collected packages: multidict, yarl, async-timeout, aiohttp, alpha-vantage
# Successfully installed aiohttp-3.6.2 alpha-vantage-2.1.3 async-timeout-3.0.1 multidict-4.7.5 yarl-1.4.2

# %%
#!pip install alpha_vantage
#!pip install git+https://github.com/RomelTorres/alpha_vantage.git@develop

from alpha_vantage.timeseries import TimeSeries
from alpha_vantage.techindicators import TechIndicators
from matplotlib.pyplot import figure
import matplotlib.pyplot as plt




# Asset here
asset = '^BVSP'
# Your key here
key = 'YC59QBJ2WVKE0SM0'
# Chose your output format, or default to JSON (python dict)
ts = TimeSeries(key, output_format='pandas')
ti = TechIndicators(key)

# Get the data, returns a tuple
# aapl_data is a pandas dataframe, aapl_meta_data is a dict
aapl_data, aapl_meta_data = ts.get_daily(symbol=asset)
# aapl_sma is a dict, aapl_meta_sma also a dict
aapl_sma, aapl_meta_sma = ti.get_sma(symbol=asset)


# Visualization
figure(num=None, figsize=(15, 6), dpi=80, facecolor='w', edgecolor='k')
aapl_data['4. close'].plot()
plt.tight_layout()
plt.grid()
plt.show()
